# %% [markdown]
# # Customer List Cleanup

# %%
# Import pandas as pd
import pandas as pd

# %%
df = pd.read_csv('customer_list_updated.csv')
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 1 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   cust_id|date|time|name|email|phone|sms-opt-out   521 non-null    object
# dtypes: object(1)
# memory usage: 4.2+ KB
#           cust_id|date|time|name|email|phone|sms-opt-out
# count                                                 521
# unique                                                521
# top     521|2023-08-01|18:10:30|Linda Flynn-Fletcher|l...
# freq                                                    1

# %%
df.columns
# Out:
# Index(['cust_id|date|time|name|email|phone|sms-opt-out '], dtype='object')

# %%
df[['cust_id','date','time','name','email','phone','sms-opt-out']] = df['cust_id|date|time|name|email|phone|sms-opt-out '].str.split('|', expand=True)
df
# Out:
#        cust_id|date|time|name|email|phone|sms-opt-out  cust_id        date  \
# 0    1|2023-03-15|08:45:12|Rachel|rachel@centralper...       1  2023-03-15
# 1    2|2023-05-22|12:30:45|R&! Geller|rossg@central...       2  2023-05-22
# 2    3|2023-07-09|18:15:27|Monica Geller|chefmonica...       3  2023-07-09
# 3    4|2023-09-01|21:05:33|Chandler Bing|chandlerb@...       4  2023-09-01
# 4    5|2023-11-18|14:22:10|Joey|howyoudoing@central...       5  2023-11-18
# ..                                                 ...     ...         ...
# 516  517|2024-02-15|11:30:30|Perry the Platypus|age...     517  2024-02-15
# 517  518|2024-05-01|15:55:45|Baljeet|baljeet@danvil...     518  2024-05-01
# 518  519|2023-03-05|09:20:00|Buford|buford@danville...     519  2023-03-05
# 519  520|2023-05-18|13:45:15|Vanessa D.^|vanessa@da...     520  2023-05-18
# 520  521|2023-08-01|18:10:30|Linda Flynn-Fletcher|l...     521  2023-08-01
#
#          time                  name                           email  \
# 0    08:45:12                Rachel       rachel@centralperk.coffee
# 1    12:30:45            R&! Geller        rossg@centralperk.coffee
# 2    18:15:27         Monica Geller   chefmonica@centralperk.coffee
# 3    21:05:33         Chandler Bing    chandlerb@centralperk.coffee
# 4    14:22:10                  Joey  howyoudoing@centralperk.coffee
# ..        ...                   ...                             ...
# 516  11:30:30    Perry the Platypus         agentp@danvillekids.com
# 517  15:55:45               Baljeet        baljeet@danvillekids.com
# 518  09:20:00                Buford         buford@danvillekids.com
# 519  13:45:15           Vanessa D.^        vanessa@danvillekids.com
# 520  18:10:30  Linda Flynn-Fletcher          linda@danvillekids.com
#
#             phone sms-opt-out
# 0    212-555-1001           N
# 1    212-555-1002           N
# 2    212-555-1003           N
# 3    212-555-1004           Y
# 4    212-555-1005           N
# ..            ...         ...
# 516  555-555-3206           N
# 517  555-555-3207           N
# 518  555-555-3208           N
# 519  555-555-3209           N
# 520  555-555-3210           N
#
# [521 rows x 8 columns]

# %%
df = df.drop('cust_id|date|time|name|email|phone|sms-opt-out ', axis=1)
df
# Out:
#     cust_id        date      time                  name  \
# 0         1  2023-03-15  08:45:12                Rachel
# 1         2  2023-05-22  12:30:45            R&! Geller
# 2         3  2023-07-09  18:15:27         Monica Geller
# 3         4  2023-09-01  21:05:33         Chandler Bing
# 4         5  2023-11-18  14:22:10                  Joey
# ..      ...         ...       ...                   ...
# 516     517  2024-02-15  11:30:30    Perry the Platypus
# 517     518  2024-05-01  15:55:45               Baljeet
# 518     519  2023-03-05  09:20:00                Buford
# 519     520  2023-05-18  13:45:15           Vanessa D.^
# 520     521  2023-08-01  18:10:30  Linda Flynn-Fletcher
#
#                               email         phone sms-opt-out
# 0         rachel@centralperk.coffee  212-555-1001           N
# 1          rossg@centralperk.coffee  212-555-1002           N
# 2     chefmonica@centralperk.coffee  212-555-1003           N
# 3      chandlerb@centralperk.coffee  212-555-1004           Y
# 4    howyoudoing@centralperk.coffee  212-555-1005           N
# ..                              ...           ...         ...
# 516         agentp@danvillekids.com  555-555-3206           N
# 517        baljeet@danvillekids.com  555-555-3207           N
# 518         buford@danvillekids.com  555-555-3208           N
# 519        vanessa@danvillekids.com  555-555-3209           N
# 520          linda@danvillekids.com  555-555-3210           N
#
# [521 rows x 7 columns]

# %%
df = df.set_index('cust_id')
df
# Out:
#                date      time                  name  \
# cust_id
# 1        2023-03-15  08:45:12                Rachel
# 2        2023-05-22  12:30:45            R&! Geller
# 3        2023-07-09  18:15:27         Monica Geller
# 4        2023-09-01  21:05:33         Chandler Bing
# 5        2023-11-18  14:22:10                  Joey
# ...             ...       ...                   ...
# 517      2024-02-15  11:30:30    Perry the Platypus
# 518      2024-05-01  15:55:45               Baljeet
# 519      2023-03-05  09:20:00                Buford
# 520      2023-05-18  13:45:15           Vanessa D.^
# 521      2023-08-01  18:10:30  Linda Flynn-Fletcher
#
#                                   email         phone sms-opt-out
# cust_id
# 1             rachel@centralperk.coffee  212-555-1001           N
# 2              rossg@centralperk.coffee  212-555-1002           N
# 3         chefmonica@centralperk.coffee  212-555-1003           N
# 4          chandlerb@centralperk.coffee  212-555-1004           Y
# 5        howyoudoing@centralperk.coffee  212-555-1005           N
# ...                                 ...           ...         ...
# 517             agentp@danvillekids.com  555-555-3206           N
# 518            baljeet@danvillekids.com  555-555-3207           N
# 519             buford@danvillekids.com  555-555-3208           N
# 520            vanessa@danvillekids.com  555-555-3209           N
# 521              linda@danvillekids.com  555-555-3210           N
#
# [521 rows x 6 columns]

# %%
# Drop duplicate rows
df = df.drop_duplicates()
df

# %% [markdown]
# Dropping any duplicate rows just in case they were present but no rows were dropped so no duplicate rows existed in the dataset.
